# %%
# Import all the required Library 
import warnings
warnings.filterwarnings('ignore')

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Now load data set
data = pd.read_csv('D:\python\DSData-master\happiness_score_dataset.csv')

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# Here data is having 158 rows × 12 columns.
#
# Country, Region is categorical data, Happiness Rank is ordinal and other data are continuous in nature.
#
# Happiness Score is dependent(target) variable and other are independent(input variable).

# %%
data.head(2)  #CHecking the first two rows of the data
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %% [markdown]
# Using Head(2), we can check top two rows of data.

# %%
df=data.iloc[:,[0,1,2,4,5,6,7,8,9,10,11,3]]

# %% [markdown]
# Happiness score is our target column, so we are changing its loaction

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 153         0.03464                   0.22208  0.77370
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual  Happiness Score
# 0       0.29678            2.51738            7.587
# 1       0.43630            2.70201            7.561
# 2       0.34139            2.49204            7.527
# 3       0.34699            2.46531            7.522
# 4       0.45811            2.45176            7.427
# ..          ...                ...              ...
# 153     0.22628            0.67042            3.465
# 154     0.18260            1.63328            3.340
# 155     0.47179            0.32858            3.006
# 156     0.19727            1.83302            2.905
# 157     0.16681            1.56726            2.839
#
# [158 rows x 12 columns]

# %%
data.shape
# Out:
# (158, 12)

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# We can see our data is not having any null values.

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# Happiness Score                  float64
# dtype: object

# %% [markdown]
# We can see Country,Region are object type, Happiness Rank is integer and other variables are float type.

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# Happiness Score                  157
# dtype: int64

# %%
df.Region.unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df.head(2)
# Out:
#        Country          Region  Happiness Rank  Standard Error  \
# 0  Switzerland  Western Europe               1         0.03411
# 1      Iceland  Western Europe               2         0.04884
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  \
# 0                        0.41978     0.29678            2.51738
# 1                        0.14145     0.43630            2.70201
#
#    Happiness Score
# 0            7.587
# 1            7.561

# %% [markdown]
# Here we will perform bivariate analysis using scatter plot.

# %%
sns.scatterplot(x='Region',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %% [markdown]
# After analyzing the scatter plot we can see some of the data is not normally distributed and it is not having linear relationship'

# %% [markdown]
# Now apply Multivariate analysis using pair plot.

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
#  11  Happiness Score                158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %% [markdown]
# Hare country and Region are object type and other data is float type

# %%
df.describe()
# Out:
#        Happiness Rank  Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000      158.000000                158.000000  158.000000
# mean        79.493671        0.047885                  0.846137    0.991046
# std         45.754363        0.017146                  0.403121    0.272369
# min          1.000000        0.018480                  0.000000    0.000000
# 25%         40.250000        0.037268                  0.545808    0.856823
# 50%         79.500000        0.043940                  0.910245    1.029510
# 75%        118.750000        0.052300                  1.158448    1.214405
# max        158.000000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual  Happiness Score
# count  158.000000         158.000000       158.000000
# mean     0.237296           2.098977         5.375734
# std      0.126685           0.553550         1.145010
# min      0.000000           0.328580         2.839000
# 25%      0.150553           1.759410         4.526000
# 50%      0.216130           2.095415         5.232500
# 75%      0.309883           2.462415         6.243750
# max      0.795880           3.602140         7.587000

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# Happiness Score                  0.097769
# dtype: float64

# %% [markdown]
# Here we can see skewness is present inside our dataset.
# Standard Error ,Trust (Government Corruption), Generosity,Health (Life Expectancy) having more skewness.

# %%
df= df.drop(['Country','Happiness Rank'], axis=1)

# %% [markdown]
# Here we are deleting  Country, Happiness Rank columns as it is not having any effect target.

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Region'] = le.fit_transform(df['Region'])

# %%
collist=df.columns.values
ncol= 10
nrows= 10
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(y=df[collist[i]],color='green', orient='x')
    plt.tight_layout()

# %% [markdown]
# Here we observed our data is having outliers.

# %%
sns.distplot(df['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'])
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %%
sns.distplot(df['Happiness Score'])
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %% [markdown]
# Using distplot we have observed that data is having skewness.

# %%
df.corr()
# Out:
#                                  Region  Standard Error  \
# Region                         1.000000       -0.022600
# Standard Error                -0.022600        1.000000
# Economy (GDP per Capita)      -0.260139       -0.217651
# Family                        -0.168533       -0.120728
# Health (Life Expectancy)      -0.357508       -0.310287
# Freedom                        0.092567       -0.129773
# Trust (Government Corruption)  0.165040       -0.178325
# Generosity                     0.273557       -0.088439
# Dystopia Residual             -0.057276        0.083981
# Happiness Score               -0.176791       -0.177254
#
#                                Economy (GDP per Capita)    Family  \
# Region                                        -0.260139 -0.168533
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Trust (Government Corruption)                  0.307885  0.205605
# Generosity                                    -0.010465  0.087513
# Dystopia Residual                              0.040059  0.148117
# Happiness Score                                0.780966  0.740605
#
#                                Health (Life Expectancy)   Freedom  \
# Region                                        -0.357508  0.092567
# Standard Error                                -0.310287 -0.129773
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.531104  0.441518
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.248335  0.493524
# Generosity                                     0.108335  0.373916
# Dystopia Residual                              0.018979  0.062783
# Happiness Score                                0.724200  0.568211
#
#                                Trust (Government Corruption)  Generosity  \
# Region                                              0.165040    0.273557
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
# Happiness Score                                     0.395199    0.180319
#
#                                Dystopia Residual  Happiness Score
# Region                                 -0.057276        -0.176791
# Standard Error                          0.083981        -0.177254
# Economy (GDP per Capita)                0.040059         0.780966
# Family                                  0.148117         0.740605
# Health (Life Expectancy)                0.018979         0.724200
# Freedom                                 0.062783         0.568211
# Trust (Government Corruption)          -0.033105         0.395199
# Generosity                             -0.101301         0.180319
# Dystopia Residual                       1.000000         0.530474
# Happiness Score                         0.530474         1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=1,linecolor='black',fmt=' .2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here Region , Standard error are having very less relationship with target.
#
# Economy (GDP per Capita),Health (Life Expectancy),Family, Trust (Government Corruption), Dystopia Residual	Happiness Having strog relationship.

# %% [markdown]
# Removing outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
# array([[1.30025593, 0.80592569, 1.36962124, ..., 0.47103971, 0.75825809,
#         1.93736005],
#        [1.30025593, 0.05588945, 1.13522625, ..., 1.57585637, 1.09285682,
#         1.91458063],
#        [1.30025593, 0.8544869 , 1.19286069, ..., 0.8242928 , 0.71233526,
#         1.88479215],
#        ...,
#        [0.37544095, 0.13253425, 0.45524543, ..., 1.85689094, 3.20843049,
#         2.0761992 ],
#        [0.96511655, 2.26396166, 2.06756644, ..., 0.31694987, 0.48198451,
#         2.1646885 ],
#        [0.96511655, 1.13418227, 1.58633379, ..., 0.5581534 , 0.96361241,
#         2.22251319]])

# %%
z.shape
# Out:
# (158, 10)

# %%
threshold= 3 
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
df_new = df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (158, 10)
# (149, 10)

# %%
Loss_percentage=(158-149)/158*100
print(Loss_percentage)
# Out:
# 5.69620253164557

# %% [markdown]
# Now split data in dependent and indipendent variable

# %%
df.head()
# Out:
#    Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0       9         0.03411                   1.39651  1.34951
# 1       9         0.04884                   1.30232  1.40223
# 2       9         0.03328                   1.32548  1.36058
# 3       9         0.03880                   1.45900  1.33095
# 4       5         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Happiness Score
# 0     0.29678            2.51738            7.587
# 1     0.43630            2.70201            7.561
# 2     0.34139            2.49204            7.527
# 3     0.34699            2.46531            7.522
# 4     0.45811            2.45176            7.427

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %% [markdown]
# Dependent variable if stored in y and indipendent variables are saved in x

# %%
x.shape
# Out:
# (158, 9)

# %%
y.shape
# Out:
# (158,)

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.24453048, -0.9722262 ,  1.44606102, ...,  1.7739906 ,
#          0.62239051,  0.75099154],
#        [ 1.24453048,  0.30934971,  1.17332111, ...,  0.31599326,
#          1.48099498,  1.11001108],
#        [ 1.24453048, -1.06201663,  1.23983558, ...,  1.90679206,
#          0.92797276,  0.70227525],
#        ...,
#        [-0.30300992,  0.39913743, -0.51346881, ...,  0.73891461,
#          1.65933595, -2.86621553],
#        [ 0.95510156,  1.92690191, -1.89495383, ..., -0.15194623,
#         -0.19482942, -0.51480136],
#        [ 0.95510156,  1.31032295, -1.52122583, ..., -0.06732622,
#         -0.49041465, -0.97664547]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sdc=StandardScaler()
xsdc=sdc.fit_transform(x)

# %%
x=pd.DataFrame(xsdc)

# %%
x
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.244530 -0.972226  1.446061  1.669206  1.491765  1.756335  1.773991
# 1    1.244530  0.309350  1.173321  2.012132  1.532348  1.439946  0.315993
# 2    1.244530 -1.062017  1.239836  1.739586  1.085223  1.615733  1.906792
# 3    1.244530 -0.503610  1.630246  1.553118  1.147600  1.792821  1.624007
# 4    0.030337 -0.823548  1.242168  1.501726  1.270179  1.475479  1.503484
# ..        ...       ...       ...       ...       ...       ...       ...
# 153  0.955102 -0.916014 -1.494046 -0.959885 -0.939459  1.135229  2.012856
# 154  0.955102 -0.719479 -1.360829 -1.896644 -1.276496  0.307514 -0.433835
# 155 -0.303010  0.399137 -0.513469 -1.690664  0.262933 -1.668658  0.738915
# 156  0.955102  1.926902 -1.894954 -1.796803 -1.525700 -1.849903 -0.151946
# 157  0.955102  1.310323 -1.521226 -2.160397 -1.371811 -0.508362 -0.067326
#
#             7         8
# 0    0.622391  0.750992
# 1    1.480995  1.110011
# 2    0.927973  0.702275
# 3    0.964080  0.651035
# 4    1.592224  0.625118
# ..        ...       ...
# 153  0.065304 -2.393259
# 154 -0.334169 -0.863565
# 155  1.659336 -2.866216
# 156 -0.194829 -0.514801
# 157 -0.490415 -0.976645
#
# [158 rows x 9 columns]

# %% [markdown]
# importing methods to perform taring and testing of the data.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
lm=LinearRegression()
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# Splitting the dataFrame

# %%
for i in range(0, 500):
    x_train, x_test, y_train, y_test= train_test_split(x,y,random_state= i,test_size=0.20)
    lm.fit(x_train,y_train)
    pred_train= lm.predict(x_train)
    pred_test= lm.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,1)==round(r2_score(y_test,pred_test)*100,1):
        print("At Random state",i, "The model perform very well")
        print("At random State:",i)
        print("Training r2_score",r2_score(y_train,pred_train)*100)
        print("testing r2 score ",r2_score(y_test,pred_test)*100)
# Out:
# At Random state 0 The model perform very well
# At random State: 0
# Training r2_score 99.28858972115165
# testing r2 score  99.30725095277582
# At Random state 1 The model perform very well
# At random State: 1
# Training r2_score 99.28498769132503
# testing r2 score  99.28058252670516
# At Random state 6 The model perform very well
# At random State: 6
# Training r2_score 99.267628589634
# testing r2 score  99.33308801676387
# At Random state 11 The model perform very well
# At random State: 11
# Training r2_score 99.27912030268868
# testing r2 score  99.31494771428437
# At Random state 68 The model perform very well
# At random State: 68
# Training r2_score 99.28681451146186
# testing r2 score  99.31069127917613
# At Random state 69 The model perform very well
# At random State: 69
# Training r2_score 99.28532567658308
# testing r2 score  99.26434379438133
# At Random state 89 The model perform very well
# At random State: 89
# Training r2_score 99.26500879152388
# testing r2 score  99.27895965181295
# At Random state 109 The model perform very well
# At random State: 109
# Training r2_score 99.27138042325106
# testing r2 score  99.30992086018288
# At Random state 119 The model perform very well
# At random State: 119
# Training r2_score 99.26850291278429
# testing r2 score  99.3127692283862
# At Random state 124 The model perform very well
# At random State: 124
# Training r2_score 99.26944592280694
# testing r2 score  99.31267970519411
# At Random state 138 The model perform very well
# At random State: 138
# Training r2_score 99.27246702242834
# testing r2 score  99.30394696908309
# At Random state 143 The model perform very well
# At random State: 143
# Training r2_score 99.25571718329424
# testing r2 score  99.34797014185456
# At Random state 174 The model perform very well
# At random State: 174
# Training r2_score 99.26722670977728
# testing r2 score  99.34586513597279
# At Random state 182 The model perform very well
# At random State: 182
# Training r2_score 99.27384537301396
# testing r2 score  99.34914009330768
# At Random state 188 The model perform very well
# At random State: 188
# Training r2_score 99.2951015110147
# testing r2 score  99.26201741294942
# At Random state 191 The model perform very well
# At random State: 191
# Training r2_score 99.29269467365877
# testing r2 score  99.25867123230307
# At Random state 192 The model perform very well
# At random State: 192
# Training r2_score 99.26469743165545
# testing r2 score  99.31973645674425
# At Random state 195 The model perform very well
# At random State: 195
# Training r2_score 99.2641777643242
# testing r2 score  99.28910259560824
# At Random state 196 The model perform very well
# At random State: 196
# Training r2_score 99.26268993142432
# testing r2 score  99.34959084920415
# At Random state 207 The model perform very well
# At random State: 207
# Training r2_score 99.28502481974328
# testing r2 score  99.29576657808771
# At Random state 217 The model perform very well
# At random State: 217
# Training r2_score 99.28953659440373
# testing r2 score  99.27733590347502
# At Random state 221 The model perform very well
# At random State: 221
# Training r2_score 99.28488381492431
# testing r2 score  99.307741071719
# At Random state 234 The model perform very well
# At random State: 234
# Training r2_score 99.28012350822664
# testing r2 score  99.34639224010489
# At Random state 240 The model perform very well
# At random State: 240
# Training r2_score 99.2868920259219
# testing r2 score  99.31515109648615
# At Random state 242 The model perform very well
# At random State: 242
# Training r2_score 99.30369821986429
# testing r2 score  99.25398913300707
# At Random state 246 The model perform very well
# At random State: 246
# Training r2_score 99.28689088439069
# testing r2 score  99.32761588860947
# At Random state 250 The model perform very well
# At random State: 250
# Training r2_score 99.29519602996128
# testing r2 score  99.29807751941469
# At Random state 274 The model perform very well
# At random State: 274
# Training r2_score 99.30152632530364
# testing r2 score  99.26422586179604
# At Random state 275 The model perform very well
# At random State: 275
# Training r2_score 99.27411447825966
# testing r2 score  99.32498912406201
# At Random state 287 The model perform very well
# At random State: 287
# Training r2_score 99.27188182839625
# testing r2 score  99.30640901651635
# At Random state 290 The model perform very well
# At random State: 290
# Training r2_score 99.27650218178529
# testing r2 score  99.30075135533055
# At Random state 302 The model perform very well
# At random State: 302
# Training r2_score 99.25822527903217
# testing r2 score  99.32081288810032
# At Random state 306 The model perform very well
# At random State: 306
# Training r2_score 99.28324005911703
# testing r2 score  99.2679563985583
# At Random state 319 The model perform very well
# At random State: 319
# Training r2_score 99.2675151667053
# testing r2 score  99.33857675922476
# At Random state 321 The model perform very well
# At random State: 321
# Training r2_score 99.27652669965013
# testing r2 score  99.34775402543849
# At Random state 331 The model perform very well
# At random State: 331
# Training r2_score 99.27554686743764
# testing r2 score  99.29258056888882
# At Random state 332 The model perform very well
# At random State: 332
# Training r2_score 99.28803828682753
# testing r2 score  99.28564365148466
# At Random state 333 The model perform very well
# At random State: 333
# Training r2_score 99.27953295276193
# testing r2 score  99.31855137451055
# At Random state 349 The model perform very well
# At random State: 349
# Training r2_score 99.27749438505846
# testing r2 score  99.33463582032948
# At Random state 351 The model perform very well
# At random State: 351
# Training r2_score 99.29820047072108
# testing r2 score  99.25249447995208
# At Random state 369 The model perform very well
# At random State: 369
# Training r2_score 99.27611210553412
# testing r2 score  99.33473017746385
# At Random state 370 The model perform very well
# At random State: 370
# Training r2_score 99.26463328359971
# testing r2 score  99.29200150768736
# At Random state 384 The model perform very well
# At random State: 384
# Training r2_score 99.28059572077417
# testing r2 score  99.30908091354273
# At Random state 395 The model perform very well
# At random State: 395
# Training r2_score 99.27176664994319
# testing r2 score  99.34248341800121
# At Random state 406 The model perform very well
# At random State: 406
# Training r2_score 99.2830368492862
# testing r2 score  99.32241785391295
# At Random state 409 The model perform very well
# At random State: 409
# Training r2_score 99.28617802631021
# testing r2 score  99.26764582298372
# At Random state 412 The model perform very well
# At random State: 412
# Training r2_score 99.26346094450618
# testing r2 score  99.31086500151982
# At Random state 423 The model perform very well
# At random State: 423
# Training r2_score 99.26736803246344
# testing r2 score  99.29789390810677
# At Random state 427 The model perform very well
# At random State: 427
# Training r2_score 99.29994219583462
# testing r2 score  99.2596644936823
# At Random state 428 The model perform very well
# At random State: 428
# Training r2_score 99.29237839102358
# testing r2 score  99.27503189816885
# At Random state 438 The model perform very well
# At random State: 438
# Training r2_score 99.26431107977857
# testing r2 score  99.27550525295929
# At Random state 451 The model perform very well
# At random State: 451
# Training r2_score 99.26001868109411
# testing r2 score  99.34547314500306
# At Random state 464 The model perform very well
# At random State: 464
# Training r2_score 99.2882501499939
# testing r2 score  99.2833506119609
# At Random state 474 The model perform very well
# At random State: 474
# Training r2_score 99.28715137423362
# testing r2 score  99.29445571639037
# At Random state 476 The model perform very well
# At random State: 476
# Training r2_score 99.28859568103051
# testing r2 score  99.30966229729879
# At Random state 484 The model perform very well
# At random State: 484
# Training r2_score 99.27790517783734
# testing r2 score  99.32984421173975
# At Random state 485 The model perform very well
# At random State: 485
# Training r2_score 99.28692382487655
# testing r2 score  99.2876391424744
# At Random state 493 The model perform very well
# At random State: 493
# Training r2_score 99.28519230478582
# testing r2 score  99.31644570006434
# At Random state 495 The model perform very well
# At random State: 495
# Training r2_score 99.28558614093012
# testing r2 score  99.31864570203305

# %% [markdown]
# Here we observed best rabdom stat is 182 giving high value of r2 score

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25,random_state=182)

# %%
models=[KNeighborsRegressor(),SVR(),DecisionTreeRegressor(),LinearRegression(),Ridge(),Lasso(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]

# %%
maelist=[]
mselist=[]
rmselist=[]
r2list=[]
def create_model(model):
    m=model
    m.fit(x_train,y_train)
    p=m.predict(x_test)
    
    mae=mean_absolute_error(p,y_test)
    mse=mean_squared_error(p,y_test)
    rmse=np.sqrt(mean_squared_error(p,y_test))
    r2=r2_score(y_test,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('---------------------------------------------------------------------------------------------------------')

# %% [markdown]
# Here we are training and testing our data with multiple model to find out the best suitable model.

# %%
for i in models:
    create_model(i)
# Out:
# KNeighborsRegressor()
# Mean absolute error 0.4035350000000001
# Mean squared error 0.23962755699999994
# Root Mean squared error 0.48951767792389267
# R2 Score 0.7856914565322832
# ---------------------------------------------------------------------------------------------------------
# SVR()
# Mean absolute error 0.22820394364750407
# Mean squared error 0.160552972498826
# Root Mean squared error 0.40069061942953693
# R2 Score 0.8564110317010168
# ---------------------------------------------------------------------------------------------------------
# DecisionTreeRegressor()
# Mean absolute error 0.4980500000000001
# Mean squared error 0.4085889000000001
# Root Mean squared error 0.6392095900407002
# R2 Score 0.6345825449613185
# ---------------------------------------------------------------------------------------------------------
# LinearRegression()
# Mean absolute error 0.06572060015507289
# Mean squared error 0.007157973297230441
# Root Mean squared error 0.08460480658467603
# R2 Score 0.9935983371415406
# ---------------------------------------------------------------------------------------------------------
# Ridge()
# Mean absolute error 0.06642504661234978
# Mean squared error 0.007442451510156137
# Root Mean squared error 0.08626964419861796
# R2 Score 0.9933439168560623
# ---------------------------------------------------------------------------------------------------------
# Lasso()
# Mean absolute error 0.8878677966101695
# Mean squared error 1.1187214978741742
# Root Mean squared error 1.0576963164699849
# R2 Score -0.0005175437958360174
# ---------------------------------------------------------------------------------------------------------
# RandomForestRegressor()
# Mean absolute error 0.3123092500000003
# Mean squared error 0.21251439634250024
# Root Mean squared error 0.46099283762603105
# R2 Score 0.8099398444975914
# ---------------------------------------------------------------------------------------------------------
# AdaBoostRegressor()
# Mean absolute error 0.35655514484383083
# Mean squared error 0.2611696324033502
# Root Mean squared error 0.5110475833064375
# R2 Score 0.7664255137468976
# ---------------------------------------------------------------------------------------------------------
# GradientBoostingRegressor()
# Mean absolute error 0.283033189046985
# Mean squared error 0.16833031796034492
# Root Mean squared error 0.4102807794186134
# R2 Score 0.8494554394529041
# ---------------------------------------------------------------------------------------------------------

# %%
print('Minimum Mean Absolute error is shown by ',models[maelist.index(min(maelist))],min(maelist))
print('Minimum Mean squared error is shown by ',models[mselist.index(min(mselist))],min(mselist))
print('Minimum Root Mean squared error is shown by ',models[rmselist.index(min(rmselist))],min(rmselist))
print('Maximun R2 Score is shown by ',models[r2list.index(max(r2list))],max(r2list))
# Out:
# Minimum Mean Absolute error is shown by  LinearRegression() 0.06572060015507289
# Minimum Mean squared error is shown by  LinearRegression() 0.007157973297230441
# Minimum Root Mean squared error is shown by  LinearRegression() 0.08460480658467603
# Maximun R2 Score is shown by  LinearRegression() 0.9935983371415406

# %% [markdown]
# Saving the best model

# %%
lrm=LinearRegression()
lrm.fit(x,y)
# Out:
# LinearRegression()

# %%
import pickle
filename='World_Happiness_Report.pkl'
pickle.dump(lrm,open(filename,'wb'))

# %% [markdown]
# Here we have saved LinearRegression as best fit model with r2 score 0.9935983371415406

# %% [markdown]
# # Conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted= np.array(lrm.predict(x_test))
df_com= pd.DataFrame({'original':a, 'predicted':predicted}, index= range(len(a)))
df_com
# Out:
#     original  predicted
# 0      5.878   5.904081
# 1      4.874   4.946368
# 2      4.610   4.562747
# 3      5.833   5.820609
# 4      4.800   4.879195
# 5      7.226   7.334715
# 6      6.983   7.028110
# 7      5.984   6.048832
# 8      5.268   5.236130
# 9      4.194   4.166128
# 10     4.297   4.281882
# 11     4.571   4.539599
# 12     6.302   6.324462
# 13     6.411   6.335733
# 14     3.904   3.857586
# 15     5.709   5.620158
# 16     5.007   4.984394
# 17     4.681   4.709517
# 18     7.187   7.205373
# 19     4.077   4.023144
# 20     3.006   3.278515
# 21     4.514   4.393541
# 22     3.819   3.862542
# 23     6.940   6.990292
# 24     5.754   5.714499
# 25     5.605   5.506330
# 26     6.168   6.114798
# 27     5.824   5.738968
# 28     5.477   5.346625
# 29     6.575   6.623446
# 30     3.465   3.339625
# 31     5.589   5.544768
# 32     5.548   5.529269
# 33     5.192   5.187918
# 34     6.853   6.801218
# 35     6.485   6.500844
# 36     4.517   4.647384
# 37     5.212   5.154944
# 38     6.670   6.676145
# 39     4.739   4.683622
